# %%
import numpy as np
import pandas as pd
df=pd.read_csv('cleaned_data')

# %%
df
# Out:
#       Unnamed: 0          region               province                  name  \
# 0              0  Emilia_Romagna                Ferrara             Comacchio
# 1              1  Emilia_Romagna                Ferrara             Lagosanto
# 2              2  Emilia_Romagna                Ferrara                  Goro
# 3              3  Emilia_Romagna                Ferrara                Mesola
# 4              4          Puglia  Barletta-Andria-Trani  Margherita di Savoia
# ...          ...             ...                    ...                   ...
# 4336        4336          Veneto                Vicenza              unknown2
# 4337        4337       Lombardia                 Varese              unknown3
# 4338        4338          Veneto                Belluno              unknown4
# 4339        4339          Veneto                Vicenza              unknown5
# 4340        4340          Veneto                Vicenza              unknown6
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# region        0
# province      0
# name          0
# tc            0
# cres          0
# csor          0
# istat         0
# area          0
# pop           0
# alt           0
# isle          0
# sea           0
# pden          0
# wden          0
# urb           0
# fee           0
# d_fee         0
# sample        0
# organic       0
# paper         0
# glass         0
# wood          0
# metal         0
# plastic       0
# raee          0
# texile        0
# other         0
# msw_so        0
# msw_un        0
# msw           0
# sor           0
# geo           0
# roads         0
# s_wteregio    0
# s_landfill    0
# gdp           0
# proads        0
# wage          0
# finance       0
# dtype: int64

# %%
from scipy.stats import kruskal
from scipy.stats import friedmanchisquare
data1 = df['organic']
data2 = df['paper']
data3 = df['glass']
data4 = df['wood']
data5 = df['metal']
data6 = df['plastic']
data7 = df['raee']
data8 = df['texile']
data9 = df['pop']
data10= df['tc']
data11= df['finance']

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
import seaborn as sns
from scipy.stats import mannwhitneyu

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
def perf_mannwhitney_test(x1, x2):
    x = StandardScaler().fit_transform(np.array(x1).reshape(-1,1))
    y = StandardScaler().fit_transform(np.array(x2).reshape(-1,1))

    print(mannwhitneyu(x,y))
    
    sns.distplot(x)
    sns.distplot(y)
    plt.show()

# %%
cols_list = ['organic', 'paper', 'glass', 'wood', 'metal', 'plastic', 'raee', 'pop', 'other', 'tc']

# %%
alpha = 0.05
for col in cols_list:
    print("Test between {col} and finance".format(col=col))
    if p > alpha:
        print('Same distributions (fail to reject H0)')
    else:
        print('Different distributions (reject H0)')
    perf_mannwhitney_test(df[col], df['finance'])
# Out:
# Test between organic and finance
# Different distributions (reject H0)
# MannwhitneyuResult(statistic=array([9821441.]), pvalue=array([0.00062731]))
# Test between paper and finance
# Different distributions (reject H0)
# MannwhitneyuResult(statistic=array([9758792.]), pvalue=array([0.00393897]))
# Test between glass and finance
# Different distributions (reject H0)
# MannwhitneyuResult(statistic=array([9630144.]), pvalue=array([0.07486446]))
# Test between wood and finance
# Different distributions (reject H0)
# MannwhitneyuResult(statistic=array([9393132.]), pvalue=array([0.80381045]))
# Test between metal and finance
# Different distributions (reject H0)
# MannwhitneyuResult(statistic=array([9409753.]), pvalue=array([0.91551915]))
# Test between plastic and finance
# Different distributions (reject H0)
# MannwhitneyuResult(statistic=array([9517151.]), pvalue=array([0.41584801]))
# Test between raee and finance
# Different distributions (reject H0)
# ...

# %%
stat, p = kruskal(data1,data11)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# Out:
# Statistics=2725.960, p=0.000

# %%
from scipy.stats import wilcoxon
data1 = df['organic']
data2 = df['paper']
data11= df['finance']
stat, p = kruskal(data1,data11)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=2725.960, p=0.000
# Different distributions (reject H0)

# %%
# Kruskal-Wallis H-test
from scipy.stats import kruskal
from scipy.stats import friedmanchisquare
# generate three independent samples
data1 = df['organic']
data2 = df['paper']
data3 = df['glass']
data4 = df['wood']
data5 = df['metal']
data6 = df['plastic']
data7 = df['raee']
data8 = df['texile']
data9 = df['pop']
data10= df['tc']
data11= df['finance']
#data3 = df1['glass']
#data4 = df1['wood']
#data5 = df1['metal']
#data6 = df1['plastic']
#data7 = df1['raee']
#data8 = df1['texile']
#data9 = df1['pop']
#data10= df1['tc']
#data11= df1['finance']

# compare samples
stat, p = kruskal(data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11)
#stat, p = friedmanchisquare(data1, data2,data11)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=40580.220, p=0.000
# Different distributions (reject H0)

# %%
stat, p = friedmanchisquare(data1, data2,data11)
print('Statistics=%.3f, p=%.3f' % (stat, p)) 
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=3430.763, p=0.000
# Different distributions (reject H0)
